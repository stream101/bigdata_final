# %% [markdown]
# ### <p>In this notebook, I will do the following things: </p>
# <p>(1) Global trend analysis </p>

# %%
import pandas as pd
import numpy as np
import sklearn as sk
import sys

from find_waiting_flow import *
from AWS_keypair_management import *

# %%
import pickle
Creds= pickle.load(open('/home/ubuntu/Vault/Creds.pkl','rb'))
print Creds.keys()
print Creds['mrjob'].keys()
pair=Creds['mrjob']
key_id=pair['key_id']
secret_key=pair['secret_key']
ID=pair['ID']
print ID,key_id
# Out:
# ['launcher', 'mrjob']
# ['key_id', 'secret_key', 's3_logs', 'ID', 's3_scratch']
# lojin AKIAIQXWOHH25RD7PZ7A

# %%
job_flow_id=find_waiting_flow(key_id, secret_key)
#job_flow_id
#job_flow_id=u'j-2KCJE554SGITB'
#job_flow_id=u'j-2KCJE554SGITB'
#job_flow_id=u'j-2EFV3O64LF1U2'
#job_flow_id=u'j-G7KQYXALVHNU'
#job_flow_id=u'j-31UKS93V80CN7'
#job_flow_id=u'j-6T8VIKMY8RHX'
#job_flow_id=u'j-LTOJMJ14G840'
#job_flow_id=u'j-31M986D4Y2I02'
print job_flow_id
# Out:
# <boto.emr.emrobject.JobFlow object at 0x3485410> no_script.yoavfreund.20140610.012426.319987 j-QEERH05KMYTO WAITING
# <boto.emr.emrobject.JobFlow object at 0x3492f10> no_script.yoavfreund.20140610.012507.678804 j-NIGXU2E6YEU3 WAITING
# <boto.emr.emrobject.JobFlow object at 0x34a6550> no_script.yoavfreund.20140610.012515.693483 j-3SOQM885E1GLH WAITING
# <boto.emr.emrobject.JobFlow object at 0x38571d0> no_script.yoavfreund.20140610.012523.713192 j-34Q4HR41T9BWU WAITING
# <boto.emr.emrobject.JobFlow object at 0x386e750> no_script.yoavfreund.20140610.012531.672863 j-31PKW9W4C2YQK WAITING
# <boto.emr.emrobject.JobFlow object at 0x376dd10> no_script.yoavfreund.20140611.181703.600873 j-2N4U1USC54EM6 WAITING
# <boto.emr.emrobject.JobFlow object at 0x3773110> no_script.yoavfreund.20140611.181713.270989 j-3QZOHADZF9KY1 WAITING
# <boto.emr.emrobject.JobFlow object at 0x3773290> no_script.yoavfreund.20140611.181722.314318 j-3MR2RR5OEXRQ7 WAITING
# ...

# %%
# !ls
# Out:
# 02_Global_Trend.ipynb  gsod.head.csv  metadata	README.md

# %% [markdown]
# ### (1) Calculate the weights for each station

# %% [markdown]
# ### We save the weight data in dictionary type and then tranform it into the type of data frame.

# %%
data_in=open('Station_Count', 'r')

station_weight={}

for line in data_in.readlines():
    words=line.split('\t')
    station_name=words[0].split(',')
    station_name[0]=station_name[0].replace('"','')
    station_name[0]=station_name[0].replace('[','')
    
    weight=words[1].split(',')
    weight[0]=weight[0].replace('[','')
    weight[1]=weight[1].replace(']','')
    
    if weight[0] >= 350 and weight[1] >= 350:
        if station_weight.get(station_name[0]):
            station_weight[station_name[0]] = station_weight[station_name[0]] + int(weight[0]) + int(weight[1])
        else:
            station_weight[station_name[0]] = int(weight[0]) + int(weight[1])

#print station_weight

# %%
D_weight=pd.DataFrame((station_weight.items()), columns=['station', 'weight'])
D_weight.head(50)
# Out:
#         station  weight
# 0   CA004035200   15989
# 1   USS0006H19S   17388
# 2   USC00390043   82252
# 3   USC00043392    7843
# 4   USC00163800   83257
# 5   USC00043397   34142
# 6   CA004012400   49689
# 7   USC00235207   34444
# 8   CA006059D09   26356
# 9   USC00418845   19830
# 10  AR000087129   39248
# 11  USC00514091   17795
# 12  CA003023665    8322
# 13  USC00485055   53164
# 14  RSM00022573    9971
# 15  USC00452126    1552
# 16  CA006079415   35935
# 17  GQC00914120     158
# 18  USR0000TLGR    8076
# 19  GLE00100992   14176
# 20  USC00441999    1543
# 21  USC00485581    7123
# 22  USS0009D06S   21848
# 23  USC00346756    2006
# 24  USC00519340       2
# 25  SW000002080   34978
# 26  USC00468730    4242
# 27  USW00024239   27014
# 28  CA006110270   24283
# 29  SG000061687   22918
# 30  NOE00111102    4340
# 31  USW00024231   36783
# 32  USW00024230   45558
# 33  USW00024233   47466
# 34  USC00248324   46522
# 35  USC00404673   34197
# 36  USW00024234   23207
# ...

# %% [markdown]
# ### Read the latitude and longitude information about the stations.

# %%
data_out=open(data_dir+'/ghcnd-stations_buffered.txt','w')
for line in open(data_dir+'/ghcnd-stations.txt','r').readlines():
    line=line.rstrip()
    string=line+' '*(90-len(line))+'\n'
    data_out.write(string)
data_out.close()

colspecs = [(0, 11), (11, 21), (21, 31), (31, 38),(39,41),(41,72),(72,76),(76,80),(80,86)]
stations = pd.read_fwf(data_dir+'/ghcnd-stations_buffered.txt', colspecs=colspecs, header=None, index_col=0, names=['latitude','longitude','elevation','state','name','GSNFLAG','HCNFLAG','WMOID'])

stations.head()
# Out:
#              latitude  longitude  elevation state                   name  \
# ACW00011604   17.1167   -61.7833       10.1   NaN  ST JOHNS COOLIDGE FLD
# ACW00011647   17.1333   -61.7833       19.2   NaN               ST JOHNS
# AE000041196   25.3330    55.5170       34.0   NaN    SHARJAH INTER. AIRP
# AF000040930   35.3170    69.0170     3366.0   NaN           NORTH-SALANG
# AG000060390   36.7167     3.2500       24.0   NaN     ALGER-DAR EL BEIDA
#
#             GSNFLAG HCNFLAG  WMOID
# ACW00011604     NaN     NaN    NaN
# ACW00011647     NaN     NaN    NaN
# AE000041196     GSN     NaN  41196
# AF000040930     GSN     NaN  40930
# AG000060390     GSN     NaN  60390
#
# [5 rows x 8 columns]

# %% [markdown]
# ### Then, join the latitude/longitude and the weight information for each station.

# %%
Djoined=D_weight.join(stations,on='station')
Djoined=Djoined.drop('WMOID', 1)
Djoined=Djoined.drop('HCNFLAG', 1)
Djoined=Djoined.drop('GSNFLAG', 1)
Djoined=Djoined.drop('name', 1)
Djoined=Djoined.drop('state', 1)
Djoined=Djoined.drop('elevation', 1)
Djoined.head()
# Out:
#        station  weight  latitude  longitude
# 0  CA004035200   15989   49.1700  -104.5800
# 1  USS0006H19S   17388   41.3333  -106.5000
# 2  USC00390043   82252   43.4892   -99.0631
# 3  USC00043392    7843   34.0869  -118.4794
# 4  USC00163800   83257   30.4192   -92.0439
#
# [5 rows x 4 columns]

# %% [markdown]
# ### (2) Use KD-tree to do the partition based on the weights

# %% [markdown]
# ### In each step, we find the medium point on either latitude or longitude to do the partition as KD-tree works. The process is done recursively until we reach the given level, for example 10 levels/1024 parts. children_df stores the partition information (partition id) for each station and children_region stores the border information for each partition. One partition id correspondes to one partition area/region.

# %%
import pandas as pd

class KD_Partition(object):

    def __init__(self, df, levels):
        self.df = df
        self.levels = levels
        
        
    def get_id(self, bits):
        return sum(bit*(2**i) for bit, i in zip(bits, range(len(bits))))

    
    def execute(self, df, level, partition='latitude', N=90, S=-90, W=-180, E=180, bits=[]):
        if level <= 0:
            id = self.get_id(bits)
            df['id'] = id
            region = {'id': id, 'N': N, 'S': S, 'W': W, 'E': E, 'weight': df.weight.sum()}
            return df, region
        
        children_df = []
        children_region = []
        df = df.sort(partition)
        df['cumulative_weight'] = df.weight.cumsum()
        threshold = df.weight.sum()/2
        tree_id = 'tree' + str(level)
        df[tree_id] = df.cumulative_weight > threshold
        del df['cumulative_weight']
        half_df = df.groupby(tree_id)

        below_df = pd.DataFrame()
        above_df = pd.DataFrame()
        for flag, half in half_df:
            if flag: above_df = half
            else: below_df = half

        min_Value = above_df[partition].min()
        max_Value = below_df[partition].max()
        border = (max_Value + min_Value)/2

        for flag, child in half_df:
            if partition == 'latitude':
                if flag: S = border
                else: N = border
                child_df, child_region = self.execute(child, level-1, 'longitude', N, S, W, E, [flag]+bits)
            else:
                if flag: W = border
                else: E = border
                child_df, child_region = self.execute(child, level-1, 'latitude', N, S, W, E, [flag]+bits)
        
            children_df.append(child_df)
            children_region.append(child_region)

        return pd.concat(children_df), children_region

# %%
kd_tree = KD_Partition(Djoined, 10)
kd_df, kd_region = kd_tree.execute(Djoined, 10)

# %% [markdown]
# ### kd_df stores the partition information (partition id) for each station.

# %%
kd_df.head(50)
# Out:
#            station  weight  latitude  longitude tree10  tree9  tree8  tree7  \
# 12416  FJ000091652     516  -16.1330  -179.9830  False  False  False  False
# 17152  AYW00068701     518  -80.0167  -178.4167  False  False  False  False
# 4234   NZ000093994   47890  -29.2500  -177.9170  False  False  False  False
# 886    NZ000939870   34941  -43.9500  -176.5670  False  False  False  False
# 24807  WF000917530   27188  -13.2330  -176.1670  False  False  False  False
# 7330   TN000091780    4911  -18.6500  -173.9830  False  False  False  False
# 15102  TL000091724    1325   -9.2000  -171.9170  False  False  False  False
# 16638  KRC00914101   15203   -2.7667  -171.7167  False  False  False  False
# 1212   KRW00060702     204   -2.7333  -171.7167  False  False  False  False
# 7591   KRW00060703   13105   -2.7667  -171.7167  False  False  False  False
# 4803   AQC00914822    1725  -11.0500  -171.0833  False  False  False  False
# ...

# %%
kd_df.tail(50)
# Out:
#            station  weight  latitude  longitude tree10 tree9 tree8 tree7  \
# 15409  RSM00024688   49847    63.250    143.150   True  True  True  True
# 6588   RSM00024585    9762    64.566    143.200   True  True  True  True
# 13278  RSM00024891   10233    61.883    147.350   True  True  True  True
# 16976  RSM00024598   15112    64.167    148.033   True  True  True  True
# 20521  RSM00024790   53821    62.783    148.167   True  True  True  True
# 23419  RSM00025705   41658    62.450    152.317   True  True  True  True
# 23416  RSM00025703   53118    62.917    152.417   True  True  True  True
# 12243  RSM00025503   53947    64.750    153.967   True  True  True  True
# 17855  RSM00025715    4350    62.500    155.783   True  True  True  True
# 27024  RSM00025922   27137    60.933    155.917   True  True  True  True
# 24786  RSM00025621   38336    64.000    158.917   True  True  True  True
# 21975  RSM00025821   19654    61.950    158.967   True  True  True  True
# ...

# %% [markdown]
# ### Store the station id information into local file.

# %%
data_out=open('station_id','w')

for index in range(0, shape(kd_df)[0]):
    data_out.write(kd_df.ix[index]['station'] +','+ str(kd_df.ix[index]['id'])+'\n')
    
data_out.close()

# %% [markdown]
# ### kd_region stores the border information for each partition.

# %%
print kd_region
# Out:
# [[[[[[[[[[{'E': -157.77499999999998, 'weight': 549236, 'N': 21.370699999999999, 'S': -90, 'W': -180, 'id': 0}, {'E': -157.77499999999998, 'weight': 597021, 'N': 21.370699999999999, 'S': -90, 'W': -157.77499999999998, 'id': 1}], [{'E': -159.32429999999999, 'weight': 618479, 'N': 21.370699999999999, 'S': 21.370699999999999, 'W': -180, 'id': 2}, {'E': -159.32429999999999, 'weight': 628608, 'N': 21.370699999999999, 'S': 21.370699999999999, 'W': -159.32429999999999, 'id': 3}]], [[{'E': -155.34475, 'weight': 595483, 'N': 20.092500000000001, 'S': -90, 'W': -156.43430000000001, 'id': 4}, {'E': -155.34475, 'weight': 609030, 'N': 20.092500000000001, 'S': -90, 'W': -155.34475, 'id': 5}], [{'E': -155.81610000000001, 'weight': 601513, 'N': 20.092500000000001, 'S': 20.092500000000001, 'W': -156.43430000000001, 'id': 6}, {'E': -155.81610000000001, 'weight': 651617, 'N': 20.092500000000001, 'S': 20.092500000000001, 'W': -155.81610000000001, 'id': 7}]]], [[[{'E': -116.64150000000001, 'weight': 600342
# ...

# %% [markdown]
# ### (3) Draw the map to show the partition results.

# %% [markdown]
# ### For each partition id/part, we give different color to show. Since there are most stations in the US, the US also has the most partition parts.

# %%
from mpl_toolkits.basemap import Basemap
import numpy as np
import matplotlib.pyplot as plt

lonmin=-180;lonmax=180;latsmin=-80;latsmax=80;
plt.figure(figsize=(15,10),dpi=300)
m = Basemap(projection='merc',llcrnrlat=latsmin,urcrnrlat=latsmax, llcrnrlon=lonmin,urcrnrlon=lonmax,lat_ts=20,resolution='i')
m.drawcoastlines()
m.fillcontinents(color='coral',lake_color='aqua')
parallels = np.arange(-80,81,10.)
meridians = np.arange(10.,351.,20.)
m.drawparallels(parallels,labels=[False,True,True,False])
m.drawmeridians(meridians,labels=[True,False,False,True])
m.drawmapboundary(fill_color='aqua')
origin_color=kd_df['id'].tolist()
x,y = m(kd_df['longitude'].tolist(),kd_df['latitude'].tolist())
m.colorbar(m.scatter(x,y,c=origin_color,marker='.',zorder=15, s=5,lw=0),location='bottom',pad="5%")

plt.title('# of measurements')
plt.show()

# %% [markdown]
# ### To make the map better visualized, I give each region a random color.

# %%
from mpl_toolkits.basemap import Basemap
import numpy as np
import matplotlib.pyplot as plt
import random

lonmin=-180;lonmax=180;latsmin=-80;latsmax=80;
plt.figure(figsize=(15,10),dpi=300)
m = Basemap(projection='merc',llcrnrlat=latsmin,urcrnrlat=latsmax, llcrnrlon=lonmin,urcrnrlon=lonmax,lat_ts=20,resolution='i')
m.drawcoastlines()
m.fillcontinents(color='coral',lake_color='aqua')
parallels = np.arange(-80,81,10.)
meridians = np.arange(10.,351.,20.)
m.drawparallels(parallels,labels=[False,True,True,False])
m.drawmeridians(meridians,labels=[True,False,False,True])
m.drawmapboundary(fill_color='aqua')
origin_color=kd_df['id'].tolist()
map_color=random.sample(range(0, 1024), 1024)
random_color=[0]*len(origin_color)
for index in range(0, len(origin_color)-1):
    random_color[index]=map_color[origin_color[index]]
x,y = m(kd_df['longitude'].tolist(),kd_df['latitude'].tolist())
m.colorbar(m.scatter(x,y,c=random_color,marker='.',zorder=15, s=5,lw=0),location='bottom',pad="5%")

plt.title('# of measurements')
plt.show()

# %% [markdown]
# ### <p>(4) Get the partition level of 6 for late analysis. </p>

# %% [markdown]
# ### From notebook 03_PCA, we know that if we use 10 level partition, the intermediate results for further merging would be more than 6.3 GB, which would be impossible to calculate on the instance. Therefore, I also calculate the 6 level partition to get a smaller partition set.

# %%
kd_tree_6 = KD_Partition(Djoined, 6)
kd_df_6, kd_region_6 = kd_tree_6.execute(Djoined, 6)

# %%
data_out=open('station_id_6','w')

for index in range(0, shape(kd_df_6)[0]):
    data_out.write(kd_df_6.ix[index]['station'] +','+ str(kd_df_6.ix[index]['id'])+'\n')
    
data_out.close()

# %%
from mpl_toolkits.basemap import Basemap
import numpy as np
import matplotlib.pyplot as plt
import random

lonmin=-180;lonmax=180;latsmin=-80;latsmax=80;
plt.figure(figsize=(15,10),dpi=300)
m = Basemap(projection='merc',llcrnrlat=latsmin,urcrnrlat=latsmax, llcrnrlon=lonmin,urcrnrlon=lonmax,lat_ts=20,resolution='i')
m.drawcoastlines()
m.fillcontinents(color='coral',lake_color='aqua')
parallels = np.arange(-80,81,10.)
meridians = np.arange(10.,351.,20.)
m.drawparallels(parallels,labels=[False,True,True,False])
m.drawmeridians(meridians,labels=[True,False,False,True])
m.drawmapboundary(fill_color='aqua')
origin_color=kd_df_6['id'].tolist()
map_color=random.sample(range(0, 64), 64)
random_color=[0]*len(origin_color)
for index in range(0, len(origin_color)-1):
    random_color[index]=map_color[origin_color[index]]
x,y = m(kd_df_6['longitude'].tolist(),kd_df_6['latitude'].tolist())
m.colorbar(m.scatter(x,y,c=random_color,marker='.',zorder=15, s=5,lw=0),location='bottom',pad="5%")

plt.title('# of measurements')
plt.show()

# %% [markdown]
# ### Each region in 6-level parition is bigger than 10-level. And most partitions locates in the US.

# %% [markdown]
# ### I also save the 4-level partition information.

# %%
kd_tree_4 = KD_Partition(Djoined, 4)
kd_df_4, kd_region_4 = kd_tree_4.execute(Djoined, 4)

# %%
data_out=open('station_id_4','w')

for index in range(0, shape(kd_df_4)[0]):
    data_out.write(kd_df_4.ix[index]['station'] +','+ str(kd_df_4.ix[index]['id'])+'\n')
    
data_out.close()

# %%
from mpl_toolkits.basemap import Basemap
import numpy as np
import matplotlib.pyplot as plt
import random

lonmin=-180;lonmax=180;latsmin=-80;latsmax=80;
plt.figure(figsize=(15,10),dpi=300)
m = Basemap(projection='merc',llcrnrlat=latsmin,urcrnrlat=latsmax, llcrnrlon=lonmin,urcrnrlon=lonmax,lat_ts=20,resolution='i')
m.drawcoastlines()
m.fillcontinents(color='coral',lake_color='aqua')
parallels = np.arange(-80,81,10.)
meridians = np.arange(10.,351.,20.)
m.drawparallels(parallels,labels=[False,True,True,False])
m.drawmeridians(meridians,labels=[True,False,False,True])
m.drawmapboundary(fill_color='aqua')
origin_color=kd_df_4['id'].tolist()
map_color=random.sample(range(0, 16), 16)
random_color=[0]*len(origin_color)
for index in range(0, len(origin_color)-1):
    random_color[index]=map_color[origin_color[index]]
x,y = m(kd_df_4['longitude'].tolist(),kd_df_4['latitude'].tolist())
m.colorbar(m.scatter(x,y,c=random_color,marker='.',zorder=15, s=5,lw=0),location='bottom',pad="5%")

plt.title('# of measurements')
plt.show()
